# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url_text_1 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_1, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 1 of 94', 'Showing 1 - 50 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['Babar Azam (PAK)', '2016-2025', '131', '124', '16', '4302', '122', '39.83', '3335', '128.99', '3', '37', '8', '457', '73', '']
# ['RG Sharma (IND)', '2007-2024', '159', '151', '19', '4231', '121*', '32.05', '3003', '140.89', '5', '32', '12', '383', '205', '']
# ['V Kohli (IND)', '2010-2024', '125', '117', '31', '4188', '122*', '48.69', '3056', '137.04', '1', '38', '7', '369', '124', '']
# ['JC Buttler (ENG)', '2011-2025', '144', '132', '23', '3869', '101*', '35.49', '2597', '148.97', '1', '28', '9', '350', '172', '']
# ...

# %%
import pandas as pd
data = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', ''],

    ['Babar Azam (PAK)', '2016-2025', '131', '124', '16', '4302', '122', '39.83', '3335', '128.99', '3', '37', '8', '457', '73', ''],
    ['RG Sharma (IND)', '2007-2024', '159', '151', '19', '4231', '121*', '32.05', '3003', '140.89', '5', '32', '12', '383', '205', ''],
    ['V Kohli (IND)', '2010-2024', '125', '117', '31', '4188', '122*', '48.69', '3056', '137.04', '1', '38', '7', '369', '124', ''],
    ['JC Buttler (ENG)', '2011-2025', '144', '132', '23', '3869', '101*', '35.49', '2597', '148.97', '1', '28', '9', '350', '172', ''],
    ['PR Stirling (IRE)', '2009-2025', '153', '150', '11', '3710', '115*', '26.69', '2751', '134.86', '1', '24', '13', '430', '133', ''],
    ['MJ Guptill (NZ)', '2009-2022', '122', '118', '7', '3531', '105', '31.81', '2602', '135.70', '2', '20', '3', '309', '173', ''],
    ['Mohammad Rizwan (PAK)', '2015-2024', '106', '93', '21', '3414', '104*', '47.41', '2723', '125.37', '1', '30', '5', '285', '95', ''],
    ['DA Warner (AUS)', '2009-2024', '110', '110', '12', '3277', '100*', '33.43', '2300', '142.47', '1', '28', '6', '337', '122', ''],
    ['Muhammad Waseem (UAE)', '2021-2025', '91', '91', '5', '3184', '112', '37.02', '2098', '151.76', '3', '25', '6', '265', '187', ''],
    ['AJ Finch (AUS)', '2011-2022', '103', '103', '12', '3120', '172', '34.28', '2189', '142.53', '2', '19', '8', '309', '125', ''],
    ['Virandeep Singh (MAS)', '2019-2025', '104', '100', '19', '3083', '116*', '38.06', '2423', '127.23', '1', '22', '5', '262', '128', ''],
    ['MDKJ Perera (SL)', '2013-2025', '88', '87', '4', '2276', '101', '27.42', '1702', '133.72', '1', '16', '6', '220', '71', ''],
    ['N Pooran (WI)', '2016-2024', '106', '97', '10', '2275', '98', '26.14', '1668', '136.39', '0', '13', '3', '152', '149', ''],
    ['Babar Hayat (HKG)', '2014-2025', '98', '94', '13', '2273', '122', '28.06', '1754', '129.58', '2', '12', '7', '135', '140', ''],
    ['KL Rahul (IND)', '2016-2022', '72', '68', '8', '2265', '110*', '37.75', '1628', '139.12', '2', '22', '5', '191', '99', ''],
    ['P Nissanka (SL)', '2021-2025', '74', '73', '3', '2211', '107', '31.58', '1747', '126.55', '1', '17', '5', '225', '59', ''],
    ['S Ssesazi (UGA)', '2021-2024', '88', '86', '10', '2204', '100*', '29.00', '1789', '123.19', '1', '17', '8', '237', '73', ''],
    ['BKG Mendis (SL)', '2016-2025', '90', '90', '4', '2198', '86', '25.55', '1672', '131.45', '0', '17', '8', '193', '89', ''],
    ['BB McCullum (NZ)', '2005-2015', '71', '70', '10', '2140', '123', '35.66', '1571', '136.21', '2', '13', '3', '199', '91', ''],
    ['AD Hales (ENG)', '2011-2022', '75', '75', '8', '2074', '116*', '30.95', '1499', '138.35', '1', '12', '5', '225', '70', ''],
    ['R Sandaruwan (KUW)', '2019-2025', '77', '77', '3', '2065', '103', '27.90', '1412', '146.24', '2', '12', '8', '178', '120', ''],
    ['Mohammad Shahzad (AFG)', '2010-2023', '73', '73', '3', '2048', '118*', '29.25', '1550', '132.12', '1', '12', '4', '229', '76', ''],
    ['MR Marsh (AUS)', '2011-2025', '76', '73', '13', '1996', '103*', '33.26', '1426', '139.97', '1', '11', '3', '171', '101', ''],
    ['Sami Sohail (MWI)', '2019-2025', '66', '62', '19', '1988', '96*', '46.23', '1593', '124.79', '0', '13', '4', '164', '63', ''],
    ['Muhammad Tanveer (QAT)', '2019-2025', '72', '66', '16', '1980', '88*', '39.60', '1484', '133.42', '0', '15', '3', '143', '111', ''],
    ["KJ O'Brien (IRE)", '2008-2021', '110', '103', '10', '1973', '124', '21.21', '1507', '130.92', '1', '5', '12', '165', '82', ''],
    ['R Powell (WI)', '2017-2025', '100', '88', '13', '1969', '107', '26.25', '1389', '141.75', '1', '9', '2', '119', '129', ''],
    ['DS Airee (NEP)', '2018-2025', '90', '78', '17', '1956', '110*', '32.06', '1406', '139.11', '1', '10', '1', '139', '82', ''],
    ['LRPL Taylor (NZ/Samoa)', '2006-2025', '106', '97', '22', '1954', '63', '26.05', '1611', '121.29', '0', '7', '6', '123', '72', '']
]

# %%
header = data[0]
rows = data[1:]

df1 = pd.DataFrame(rows, columns=header)
df1 = df1.drop(columns=[''])

df1.head(5)
# Out:
#               Player       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0   Babar Azam (PAK)  2016-2025  131  124  16  4302   122  39.83  3335
# 1    RG Sharma (IND)  2007-2024  159  151  19  4231  121*  32.05  3003
# 2      V Kohli (IND)  2010-2024  125  117  31  4188  122*  48.69  3056
# 3   JC Buttler (ENG)  2011-2025  144  132  23  3869  101*  35.49  2597
# 4  PR Stirling (IRE)  2009-2025  153  150  11  3710  115*  26.69  2751
#
#        SR 100  50   0   4s   6s
# 0  128.99   3  37   8  457   73
# 1  140.89   5  32  12  383  205
# 2  137.04   1  38   7  369  124
# 3  148.97   1  28   9  350  172
# 4  134.86   1  24  13  430  133

# %% [markdown]
# # Page 2

# %%
url_text_2 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=2;template=results;type=batting"

# %%
for i in range(1,10):
    url = f'url_text_2 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class={i};page=2;template=results;type=batting'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_2, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 2 of 94', 'Showing 51 - 100 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['LRPL Taylor (NZ/Samoa)', '2006-2025', '106', '97', '22', '1954', '63', '26.05', '1611', '121.29', '0', '7', '6', '123', '72', '']
# ['JP Duminy (SA)', '2007-2019', '81', '75', '25', '1934', '96*', '38.68', '1532', '126.24', '0', '11', '6', '138', '71', '']
# ['RR Patel (KENYA)', '2008-2025', '93', '81', '17', '1930', '120', '30.15', '1420', '135.91', '1', '11', '4', '153', '103', '']
# ['GD Phillips (NZ)', '2017-2025', '83', '74', '12', '1929', '108', '31.11', '1372', '140.59', '2', '10', '3', '138', '91', '']
# ...

# %%
data2 = [
['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', ''],
['JP Duminy (SA)', '2007-2019', '81', '75', '25', '1934', '96*', '38.68', '1532', '126.24', '0', '11', '6', '138', '71', ''],
['RR Patel (KENYA)', '2008-2025', '93', '81', '17', '1930', '120', '30.15', '1420', '135.91', '1', '11', '4', '153', '103', ''],
['GD Phillips (NZ)', '2017-2025', '83', '74', '12', '1929', '108', '31.11', '1372', '140.59', '2', '10', '3', '138', '91', ''],
['Rahmanullah Gurbaz (AFG)', '2019-2025', '77', '77', '0', '1920', '100', '24.93', '1448', '132.59', '1', '10', '8', '145', '106', ''],
['CH Gayle (WI)', '2006-2021', '79', '75', '7', '1899', '117', '27.92', '1381', '137.50', '2', '14', '4', '158', '124', ''],
['DJ Malan (ENG)', '2017-2023', '62', '60', '8', '1892', '103*', '36.38', '1428', '132.49', '1', '16', '2', '194', '62', ''],
['TM Dilshan (SL)', '2006-2016', '80', '79', '12', '1889', '104*', '28.19', '1567', '120.54', '1', '13', '10', '223', '33', ''],
#                      Player       Span Mat Inns  NO  Runs   HS    Ave    BF  \
# 0            JP Duminy (SA)  2007-2019  81   75  25  1934  96*  38.68  1532
# 1          RR Patel (KENYA)  2008-2025  93   81  17  1930  120  30.15  1420
# 2          GD Phillips (NZ)  2017-2025  83   74  12  1929  108  31.11  1372
# 3  Rahmanullah Gurbaz (AFG)  2019-2025  77   77   0  1920  100  24.93  1448
# 4             CH Gayle (WI)  2006-2021  79   75   7  1899  117  27.92  1381
#
#        SR 100  50  0   4s   6s
# 0  126.24   0  11  6  138   71
# 1  135.91   1  11  4  153  103
# 2  140.59   2  10  3  138   91
# 3  132.59   1  10  8  145  106
# 4  137.50   2  14  4  158  124

# %% [markdown]
# # Page 3

# %%
url_text_3 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=3;template=results;type=batting"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_3, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 3 of 94', 'Showing 101 - 150 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['F du Plessis (SA/World)', '2012-2020', '50', '50', '7', '1528', '119', '35.53', '1137', '134.38', '1', '10', '0', '140', '50', '']
# ['LMP Simmons (WI)', '2007-2021', '68', '67', '10', '1527', '91*', '26.78', '1264', '120.80', '0', '9', '6', '140', '68', '']
# ['JJ Roy (ENG)', '2014-2022', '64', '64', '1', '1522', '78', '24.15', '1106', '137.61', '0', '8', '7', '153', '69', '']
# ['Mushfiqur Rahim (BAN)', '2006-2022', '102', '93', '16', '1500', '72*', '19.48', '1304', '115.03', '0', '6', '8', '126', '37', '']
# ...

# %%
data3 = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', ''],
    ['JJ Roy (ENG)', '2014-2022', '64', '64', '1', '1522', '78', '24.15', '1106', '137.61', '0', '8', '7', '153', '69', ''],
    ['TH David (AUS/SGP)', '2019-2025', '63', '55', '14', '1507', '102*', '36.75', '896', '168.19', '1', '8', '4', '117', '95', ''],
    ['Mushfiqur Rahim (BAN)', '2006-2022', '102', '93', '16', '1500', '72*', '19.48', '1304', '115.03', '0', '6', '8', '126', '37', ''],
    ['KJ Coetzer (SCOT)', '2008-2021', '70', '68', '2', '1495', '89', '22.65', '1254', '119.21', '0', '6', '4', '158', '48', ''],
    ['DPMD Jayawardene (SL)', '2006-2014', '55', '55', '8', '1493', '100', '31.76', '1121', '133.18', '1', '9', '4', '173', '33', ''],
    ['Bilal Zalmai (AUT)', '2019-2025', '50', '48', '6', '1485', '111*', '35.35', '921', '161.23', '1', '11', '2', '149', '86', ''],
    ['MM Ali (ENG)', '2014-2024', '92', '75', '17', '1229', '72*', '21.18', '863', '142.41', '0', '7', '9', '88', '68', '']
]

# %%
header = data3[0]
rows = data3[1:]

df3 = pd.DataFrame(rows, columns=header)
df3 = df3.drop(columns=[''])
df3.head(400)
# Out:
#                      Player       Span  Mat Inns  NO  Runs    HS    Ave    BF  \
# 0              JJ Roy (ENG)  2014-2022   64   64   1  1522    78  24.15  1106
# 1        TH David (AUS/SGP)  2019-2025   63   55  14  1507  102*  36.75   896
# 2     Mushfiqur Rahim (BAN)  2006-2022  102   93  16  1500   72*  19.48  1304
# 3         KJ Coetzer (SCOT)  2008-2021   70   68   2  1495    89  22.65  1254
# 4     DPMD Jayawardene (SL)  2006-2014   55   55   8  1493   100  31.76  1121
# 5        Bilal Zalmai (AUT)  2019-2025   50   48   6  1485  111*  35.35   921
# 6       Ahmed Shehzad (PAK)  2009-2019   59   59   2  1471  111*  25.80  1282
# 7            J Charles (WI)  2011-2025   64   63   0  1468   118  23.30  1136
# 8           AK Markram (SA)  2019-2025   62   58   8  1467    70  29.34  1006
# 9       Soumya Sarkar (BAN)  2015-2024   87   86   4  1462    68  17.82  1197
# 10          SR Watson (AUS)  2006-2016   58   56   6  1462  124*  29.24  1006
# ...

# %% [markdown]
# # Page 4

# %%
url_text_4 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=4;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_4, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 4 of 94', 'Showing 151 - 200 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['MM Ali (ENG)', '2014-2024', '92', '75', '17', '1229', '72*', '21.18', '863', '142.41', '0', '7', '9', '88', '68', '']
# ['SI Runsewe (NGA)', '2019-2025', '66', '65', '9', '1229', '80', '21.94', '1111', '110.62', '0', '8', '4', '136', '13', '']
# ['SA Edwards (NED)', '2018-2025', '82', '73', '19', '1226', '99', '22.70', '978', '125.35', '0', '2', '3', '97', '29', '']
# ['Manpreet Singh (SGP)', '2019-2025', '56', '53', '3', '1215', '71', '24.30', '941', '129.11', '0', '5', '6', '68', '50', '']
# ['S Davizi (CZK-R)', '2019-2025', '38', '37', '3', '1210', '115*', '35.58', '885', '136.72', '3', '6', '2', '132', '41', '']
# ...

# %%
data4 = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['BA Pai (GIBR)', '2019-2024', '39', '37', '7', '1054', '107*', '35.13', '915', '115.19', '1', '6', '2', '95', '17', ''],
    ['RN Patel (KENYA)', '2019-2024', '56', '54', '10', '1054', '75', '23.95', '874', '120.59', '0', '3', '6', '110', '23', ''],
    ['V Aravind (UAE)', '2020-2024', '48', '43', '5', '1052', '97*', '27.68', '936', '112.39', '0', '6', '4', '105', '23', ''],
    ['Sarfaraz Ali (BHR)', '2019-2024', '52', '52', '3', '1050', '69*', '21.42', '722', '145.42', '0', '6', '4', '91', '78', ''],
    ['Luqman Butt (CAM)', '2023-2025', '36', '33', '6', '1049', '80*', '38.85', '711', '147.53', '0', '6', '1', '95', '57', ''],
    ['JN Frylinck (NAM)', '2019-2025', '74', '55', '13', '1041', '134', '24.78', '836', '124.52', '1', '2', '3', '89', '29', '']
]

# %%
header = data4[0]
rows = data4[1:]

df4 = pd.DataFrame(rows, columns=header)

df4 = df4.drop(columns=[''])

df4.head()
# Out:
#                  Player       Span Mat Inns  NO  Runs    HS    Ave    BF  \
# 0      SI Runsewe (NGA)  2019-2025  66   65   9  1229    80  21.94  1111
# 1      SA Edwards (NED)  2018-2025  82   73  19  1226    99  22.70   978
# 2  Manpreet Singh (SGP)  2019-2025  56   53   3  1215    71  24.30   941
# 3      S Davizi (CZK-R)  2019-2025  38   37   3  1210  115*  35.58   885
# 4         RR Pant (IND)  2017-2024  76   66  14  1209   65*  23.25   950
#
#        SR 100 50  0   4s  6s
# 0  110.62   0  8  4  136  13
# 1  125.35   0  2  3   97  29
# 2  129.11   0  5  6   68  50
# 3  136.72   3  6  2  132  41
# 4  127.26   0  3  4  111  44

# %% [markdown]
# # Page 5

# %%
url_text_5 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=5;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_5, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 5 of 94', 'Showing 201 - 250 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['Luqman Butt (CAM)', '2023-2025', '36', '33', '6', '1049', '80*', '38.85', '711', '147.53', '0', '6', '1', '95', '57', '']
# ['JN Frylinck (NAM)', '2019-2025', '74', '55', '13', '1041', '134', '24.78', '836', '124.52', '1', '2', '3', '89', '29', '']
# ['Imran Anwar (BHR)', '2019-2025', '89', '61', '6', '1034', '87', '18.80', '814', '127.02', '0', '6', '8', '58', '73', '']
# ['N Nipiko (VAN)', '2019-2024', '39', '39', '6', '1031', '100', '31.24', '868', '118.77', '1', '6', '1', '80', '42', '']
# ['CJA Amini (PNG)', '2015-2024', '59', '51', '9', '1028', '91*', '24.47', '891', '115.37', '0', '5', '6', '75', '30', '']
# ...

# %%
data5 = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['Tanzid Hasan (BAN)', '2024-2025', '40', '40', '4', '906', '73*', '25.16', '714', '126.89', '0', '8', '6', '84', '42', ''],
    ['D Kansonkho (MWI)', '2019-2025', '60', '56', '5', '903', '54', '17.70', '990', '91.21', '0', '1', '4', '88', '15', ''],
    ['I Danladi (NGA)', '2019-2025', '49', '45', '4', '900', '80', '21.95', '786', '114.50', '0', '2', '1', '80', '28', ''],
    ['V Balakrishnan (BOT)', '2019-2025', '47', '44', '5', '896', '101', '22.97', '822', '109.00', '2', '3', '0', '84', '29', ''],
    ['K Nassoro (TAN)', '2021-2025', '75', '61', '11', '896', '60', '17.92', '924', '96.96', '0', '2', '4', '83', '15', ''],
    ['E Chigumbura (ZIM)', '2006-2020', '57', '56', '9', '893', '54*', '19.00', '635', '140.62', '0', '3', '6', '61', '53', ''],
    ['JE Root (ENG)', '2012-2019', '32', '30', '5', '893', '90*', '35.72', '707', '126.30', '0', '5', '2', '92', '16', ''],
    ['J Butler (GUE)', '2019-2025', '39', '37', '5', '892', '87', '27.87', '811', '109.98', '0', '3', '1', '82', '21', '']
]

# %%
header = data5[0]
rows = data5[1:]

df5 = pd.DataFrame(rows, columns=header)

df5 = df5.drop(columns=[''])

df5.head()
# Out:
#                   Player       Span Mat Inns NO  Runs   HS    Ave   BF  \
# 0      Imran Anwar (BHR)  2019-2025  89   61  6  1034   87  18.80  814
# 1         N Nipiko (VAN)  2019-2024  39   39  6  1031  100  31.24  868
# 2        CJA Amini (PNG)  2015-2024  59   51  9  1028  91*  24.47  891
# 3  E Dusingizimana (RWN)  2021-2024  62   60  3  1028  66*  18.03  966
# 4          P Kurup (BHR)  2021-2025  46   45  4  1028   74  25.07  939
#
#        SR 100 50  0   4s  6s
# 0  127.02   0  6  8   58  73
# 1  118.77   1  6  1   80  42
# 2  115.37   0  5  6   75  30
# 3  106.41   0  4  7  104  35
# 4  109.47   0  5  2  107  23

# %% [markdown]
# # Page 6

# %%
url_text_6 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=6;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_6, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 6 of 94', 'Showing 251 - 300 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['IA De Silva (BUL)', '2020-2022', '35', '34', '2', '795', '100*', '24.84', '690', '115.21', '1', '4', '3', '72', '37', ''],
    ['Yasim Murtaza (HKG)', '2022-2025', '66', '55', '8', '795', '58', '16.91', '689', '115.38', '0', '2', '1', '59', '32', ''],
    ['Basil Hameed (UAE)', '2020-2025', '64', '53', '17', '794', '51', '22.05', '625', '127.04', '0', '2', '3', '42', '41', ''],
    ['Zeeshan Kukikhel (HUN)', '2021-2025', '27', '27', '1', '793', '137', '30.50', '508', '156.10', '1', '5', '1', '83', '42', ''],
    ['Shadab Khan (PAK)', '2017-2025', '112', '58', '14', '792', '52', '18.00', '565', '140.17', '0', '1', '6', '56', '38', ''],
    ['Misbah-ul-Haq (PAK)', '2007-2012', '39', '34', '13', '788', '87*', '37.52', '715', '110.20', '0', '3', '2', '45', '26', ''],
    ['C Rubagumya (RWN)', '2021-2025', '83', '71', '13', '788', '40', '13.58', '938', '84.00', '0', '0', '11', '47', '12', ''],
    ['Mohammad Nawaz (3) (PAK)', '2016-2025', '79', '56', '14', '787', '45*', '18.73', '584', '134.76', '0', '0', '6', '59', '42', ''],
    ['Usman Ghani (AFG)', '2015-2023', '35', '34', '3', '786', '73', '25.35', '733', '107.23', '0', '4', '0', '76', '21', ''],
    ['Azyan Farhath (MDV)', '2019-2024', '35', '35', '7', '784', '66*', '28.00', '926', '84.66', '0', '5', '0', '61', '12', '']
]

# %%
header = data6[0]
rows = data6[1:]

df6 = pd.DataFrame(rows, columns=header)

df6 = df6.drop(columns=[''])
df6.head()
# Out:
#                  Player       Span Mat Inns NO Runs   HS    Ave   BF      SR  \
# 0  Muhammad Usman (UAE)  2016-2022  47   43  6  891  89*  24.08  778  114.52
# 1       Saim Ayub (PAK)  2023-2025  49   47  2  890  98*  19.77  664  134.03
# 2         G Malla (NEP)  2014-2022  45   39  1  883  107  23.23  734  120.29
# 3       JP Inglis (AUS)  2022-2025  36   35  6  878  110  30.27  534  164.41
# 4       MNM Aslam (KUW)  2019-2025  75   51  7  877   55  19.93  769  114.04
#
#   100 50  0  4s  6s
# 0   0  3  3  73  27
# 1   0  4  9  90  41
# 2   1  2  1  76  36
# 3   2  2  4  89  37
# 4   0  4  4  76  21

# %% [markdown]
# # Page 7

# %%
url_text_7 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=7;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_7, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 7 of 94', 'Showing 301 - 350 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['NR Kumar (CAN/USA)', '2012-2024', '36', '32', '4', '711', '83', '25.39', '567', '125.39', '0', '4', '2', '51', '25', ''],
    ['H Singh (GER)', '2019-2025', '42', '38', '7', '711', '70', '22.93', '558', '127.41', '0', '3', '2', '66', '18', ''],
    ['Jaker Ali (BAN)', '2023-2025', '45', '40', '13', '710', '72*', '26.29', '574', '123.69', '0', '3', '1', '38', '40', ''],
    ['A Dizija (SRB)', '2022-2025', '33', '32', '1', '709', '92', '22.87', '607', '116.80', '0', '6', '3', '69', '26', ''],
    ['J Mees (LUX)', '2019-2024', '40', '39', '7', '709', '85', '22.15', '600', '118.16', '0', '3', '4', '67', '22', ''],
    ['MK Pandey (IND)', '2015-2020', '39', '33', '17', '709', '79*', '44.31', '562', '126.15', '0', '3', '2', '49', '19', ''],
    ['W Niyitanga (RWN)', '2021-2024', '61', '60', '5', '708', '55*', '12.87', '858', '82.51', '0', '2', '7', '47', '21', ''],
    ['R Bakum (GHA)', '2019-2024', '42', '41', '4', '706', '71', '19.08', '609', '115.92', '0', '4', '4', '48', '33', ''],
    ['H Thaker (CAN)', '2019-2025', '50', '38', '9', '706', '53*', '24.34', '571', '123.64', '0', '1', '0', '42', '29', ''],
    ['Shubman Gill (IND)', '2023-2025', '28', '28', '3', '705', '126*', '28.20', '499', '141.28', '1', '3', '1', '77', '24', ''],
    ['CK Kapugedera (SL)', '2006-2017', '43', '38', '7', '703', '50', '22.67', '591', '118.95', '0', '1', '0', '58', '25', ''],
    ['Ravinderpal Singh (CAN)', '2019-2025', '43', '36', '7', '701', '101', '24.17', '497', '141.04', '1', '1', '4', '48', '38', '']
]

# %%
header = data7[0]
rows = data7[1:]

df7 = pd.DataFrame(rows, columns=header)

df7 = df7.drop(columns=[''])

df7.head()
# Out:
#             Player       Span Mat Inns NO Runs  HS    Ave   BF      SR 100 50  \
# 0    J Baker (CAY)  2024-2025  22   22  3  783  94  41.21  606  129.20   0  8
# 1  Umar Adam (MDV)  2019-2024  46   45  1  783  56  17.79  589  132.93   0  4
# 2    L Siaka (PNG)  2015-2025  64   57  5  780  55  15.00  693  112.55   0  1
# 3   KR Mayers (WI)  2020-2025  41   39  2  773  73  20.89  575  134.43   0  3
# 4  S Adedeji (NGA)  2019-2025  47   44  7  772  68  20.86  890   86.74   0  3
#
#    0  4s  6s
# 0  0  69  44
# 1  5  62  45
# 2  8  59  23
# 3  1  69  51
# 4  3  62  16

# %%
url_text_8 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=8;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_8, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 8 of 94', 'Showing 351 - 400 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['Habib Khan (EST)', '2021-2025', '26', '24', '0', '629', '90', '26.20', '482', '130.49', '0', '4', '1', '49', '34', ''],
    ['ST Jayasuriya (SL)', '2006-2011', '31', '30', '3', '629', '88', '23.29', '487', '129.15', '0', '4', '4', '76', '23', ''],
    ['B McMullen (SCOT)', '2023-2025', '23', '22', '2', '629', '96', '31.45', '431', '145.93', '0', '7', '1', '56', '30', ''],
    ['SSM Stanislaus (MLT)', '2020-2024', '40', '35', '4', '627', '62', '20.22', '607', '103.29', '0', '1', '1', '43', '23', ''],
    ['JJ Huo (MOZ)', '2019-2025', '42', '40', '9', '626', '107*', '20.19', '553', '113.20', '1', '0', '4', '64', '18', ''],
    ['Khawar Ali (OMA)', '2015-2022', '41', '35', '3', '626', '72*', '19.56', '635', '98.58', '0', '2', '2', '67', '15', ''],
    ['Khizer Ahmed (NOR)', '2019-2025', '33', '32', '4', '624', '64*', '22.28', '537', '116.20', '0', '2', '3', '61', '17', ''],
    ['D Wiese (NAM/SA)', '2013-2024', '54', '40', '14', '624', '66*', '24.00', '488', '127.86', '0', '3', '3', '35', '30', ''],
    ['MR Swart (NED)', '2012-2016', '26', '25', '2', '621', '89', '27.00', '537', '115.64', '0', '4', '1', '53', '16', ''],
    ['ZE Green (NAM)', '2019-2025', '73', '50', '15', '620', '52*', '17.71', '568', '109.15', '0', '1', '4', '53', '13', ''],
    ['Sahibzada Farhan (PAK)', '2018-2025', '28', '28', '0', '619', '74', '22.10', '496', '124.79', '0', '5', '2', '46', '36', ''],
    ['Selim Salau (NGA)', '2024-2025', '25', '24', '0', '619', '112', '25.79', '571', '108.40', '1', '0', '1', '62', '11', ''],
    ['SA Ahmad (DEN)', '2019-2025', '35', '31', '4', '616', '66', '22.81', '573', '107.50', '0', '3', '1', '56', '13', '']
]

# %%
header = data8[0]
rows = data8[1:]

df8 = pd.DataFrame(rows, columns=header)

df8 = df8.drop(columns=[''])
df8.head()
# Out:
#                  Player       Span Mat Inns  NO Runs   HS    Ave   BF      SR  \
# 0   Lakshit Gupta (CAM)  2023-2025  35   35   5  700   62  23.33  684  102.33
# 1       A Mansale (VAN)  2019-2024  34   33   4  699   82  24.10  586  119.28
# 2         IO Okpe (NGA)  2019-2025  74   62  10  699  65*  13.44  664  105.27
# 3        JO Holder (WI)  2014-2025  79   57  18  698   38  17.89  509  137.13
# 4  CJ Anderson (NZ/USA)  2012-2024  42   34   6  697  94*  24.89  553  126.03
#
#   100 50  0  4s  6s
# 0   0  3  1  58  26
# 1   0  5  5  46  26
# 2   0  2  4  25  27
# 3   0  0  9  43  43
# 4   0  3  3  40  35

# %% [markdown]
# # Page 9

# %%
url_text_9 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=9;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_9, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
data9 = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['SO Ngoche (KENYA)', '2010-2025', '104', '65', '20', '566', '41*', '12.57', '517', '109.47', '0', '0', '10', '46', '18', ''],
    ['Nurul Hasan (BAN)', '2016-2025', '53', '48', '19', '564', '42*', '19.44', '467', '120.77', '0', '0', '4', '31', '25', ''],
    ['AS Samra (PHI)', '2023-2025', '23', '23', '2', '564', '101', '26.85', '407', '138.57', '1', '3', '0', '44', '28', ''],
    ['AM Tribe (JER)', '2021-2025', '26', '24', '2', '564', '73*', '25.63', '454', '124.22', '0', '4', '1', '53', '18', ''],
    ['Agha Salman (PAK)', '2024-2025', '33', '31', '6', '563', '56', '22.52', '516', '109.10', '0', '4', '2', '47', '16', ''],
    ['M Podosky (PHI)', '2022-2025', '31', '31', '4', '563', '101', '20.85', '463', '121.59', '1', '1', '5', '43', '32', '']
]

# %%
header = data9[0]
rows = data9[1:]

df9 = pd.DataFrame(rows, columns=header)

df9 = df9.drop(columns=[''])

df9.head()
# Out:
#              Player       Span Mat Inns NO Runs   HS    Ave   BF      SR 100  \
# 0   MN Waller (ZIM)  2011-2018  32   31  8  613   68  26.65  443  138.37   0
# 1    J Bulele (MOZ)  2019-2022  27   27  2  612  62*  24.48  654   93.57   0
# 2      B Ward (JER)  2019-2025  43   34  9  608  58*  24.32  469  129.63   0
# 3  Ayaan Khan (OMA)  2021-2024  42   37  5  607  53*  18.96  562  108.00   0
# 4    RA Sealy (CAY)  2022-2025  34   32  2  606  73*  20.20  454  133.48   0
#
#   50  0  4s  6s
# 0  1  2  42  28
# 1  4  2  79   2
# 2  1  1  34  33
# 3  1  1  38  18
# 4  2  3  38  35

# %% [markdown]
# # Page 10

# %%
url_text_10 = "https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;page=10;template=results;type=batting"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/122.0.0.0 Safari/537.36"
}

# %%
response = requests.get(url_text_10, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
html_content = response.text

# %%
soup = BeautifulSoup(html_content)

# %%
soup1 = BeautifulSoup(html_content, "html.parser")
table = soup1.find("div", class_="pnl650M")

# %%
if table:
    rows = table.find_all("tr")
    for row in rows:
        cols = [td.text.strip() for td in row.find_all(["td", "th"])]
        print(cols)
else:
    print("error")
# Out:
# ['View\xa0overall figures\n[change view]']
# ['Ordered by\xa0runs scored (descending)']
# ['Page 10 of 94', 'Showing 451 - 500 of 4671', 'First\nPrevious\n\nNext \nLast', 'First\nPrevious', 'Next \nLast', 'Return to query menuCleared query menu']
# ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '0', '4s', '6s', '']
# ['AS Samra (PHI)', '2023-2025', '23', '23', '2', '564', '101', '26.85', '407', '138.57', '1', '3', '0', '44', '28', '']
# ['AM Tribe (JER)', '2021-2025', '26', '24', '2', '564', '73*', '25.63', '454', '124.22', '0', '4', '1', '53', '18', '']
# ['M Podosky (PHI)', '2022-2025', '31', '31', '4', '563', '101', '20.85', '463', '121.59', '1', '1', '5', '43', '32', '']
# ['Mohammad Ihsan (ESP)', '2022-2024', '21', '21', '5', '562', '102*', '35.12', '356', '157.86', '1', '1', '0', '60', '30', '']
# ['D Myers (ZIM)', '2021-2025', '30', '29', '3', '562', '96', '21.61', '450', '124.88', '0', '2', '2', '50', '16', '']
# ...

# %%
data10 = [
    ['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR', '100', '50', '
    ['C Green (AUS)', '2022-2025', '21', '20', '4', '521', '62*', '32.56', '325', '160.30', '0', '6', '0', '42', '31', ''],
    ['Parvez Hossain Emon (BAN)', '2022-2025', '26', '26', '1', '521', '100', '20.84', '396', '131.56', '1', '3', '7', '44', '33', ''],
    ['J Barker (LUX)', '2019-2024', '36', '31', '9', '519', '48', '23.59', '530', '97.92', '0', '0', '2', '41', '3', ''],
    ['F Behardien (SA)', '2012-2018', '38', '30', '14', '518', '64*', '32.37', '404', '128.21', '0', '1', '1', '37', '16', ''],
    ['M van Lingen (NAM)', '2021-2024', '30', '27', '0', '518', '67', '19.18', '447', '115.88', '0', '2', '2', '61', '14', ''],
    ['Jaspal Singh (MLT)', '2023-2025', '35', '35', '7', '516', '65*', '18.42', '479', '107.72', '0', '3', '2', '40', '23', ''],
    ['TWM Latham (NZ)', '2012-2023', '26', '23', '3', '516', '65*', '25.80', '474', '108.86', '0', '3', '1', '42', '8', ''],
    ['CN Ackermann (NED)', '2019-2024', '25', '25', '4', '515', '62', '24.52', '449', '114.69', '0', '1', '2', '38', '11', '']
]

# %%
header = data10[0]
rows = data10[1:]

df10 = pd.DataFrame(rows, columns=header)
df10 = df10.drop(columns=[''])

df10.head()
# Out:
#                       Player       Span Mat Inns  NO Runs    HS    Ave   BF  \
# 0       Mohammad Ihsan (ESP)  2022-2024  21   21   5  562  102*  35.12  356
# 1  RE van der Merwe (NED/SA)  2009-2025  67   44  19  561   75*  22.44  433
# 2              TS Fray (BER)  2019-2025  40   37   4  560   62*  16.96  617
# 3            SKA Awiah (GHA)  2021-2024  40   34   4  559   96*  18.63  601
# 4          OGL Bascome (BER)  2019-2025  36   34   3  559    54  18.03  436
#
#        SR 100 50  0  4s  6s
# 0  157.86   1  1  0  60  30
# 1  129.56   0  2  7  43  16
# 2   90.76   0  2  3  45   8
# 3   93.01   0  2  4  52  11
# 4  128.21   0  1  2  38  37

# %%
all_data = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9,df10])
all_data.to_csv("players_data.csv", index=False)

# %%
df = pd.read_csv("players_data.csv")
df
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave    BF  \
# 0      Babar Azam (PAK)  2016-2025  131   124  16  4302   122  39.83  3335
# 1       RG Sharma (IND)  2007-2024  159   151  19  4231  121*  32.05  3003
# 2         V Kohli (IND)  2010-2024  125   117  31  4188  122*  48.69  3056
# 3      JC Buttler (ENG)  2011-2025  144   132  23  3869  101*  35.49  2597
# 4     PR Stirling (IRE)  2009-2025  153   150  11  3710  115*  26.69  2751
# ..                  ...        ...  ...   ...  ..   ...   ...    ...   ...
# 495    F Behardien (SA)  2012-2018   38    30  14   518   64*  32.37   404
# 496  M van Lingen (NAM)  2021-2024   30    27   0   518    67  19.18   447
# 497  Jaspal Singh (MLT)  2023-2025   35    35   7   516   65*  18.42   479
# 498     TWM Latham (NZ)  2012-2023   26    23   3   516   65*  25.80   474
# 499  CN Ackermann (NED)  2019-2024   25    25   4   515    62  24.52   449
#
#          SR  100  50   0   4s   6s
# ...
